# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("KafkaSparkStreaming") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.3") \
    .getOrCreate()

# Read streaming data from Kafka

kafka_df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "kafka:9092") \
    .option("subscribe", "mytopic") \
    .option("startingOffsets", "earliest") \
    .load()

# Decode Kafka key-value data to strings
stream_df = kafka_df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# Write data to console for debugging
query = stream_df \
    .writeStream \
    .outputMode("append") \
    .format("console") \
    .start()

print(type(query))
# Out:
# <class 'pyspark.sql.streaming.query.StreamingQuery'>
# 24/12/05 18:30:49 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-05fc7521-a7bb-4e71-8fae-f7a38611a3e0. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 24/12/05 18:30:49 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 24/12/05 18:30:49 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 43:>                                                         (0 + 1) / 1]
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|54.36.149.41 - - ...|
# |NULL|31.56.96.51 - - [...|
# |NULL|31.56.96.51 - - [...|
# |NULL|40.77.167.129 - -...|
# |NULL|91.99.72.15 - - [...|
# |NULL|40.77.167.129 - -...|
# |NULL|40.77.167.129 - -...|
# |NULL|40.77.167.129 - -...|
# |NULL|66.249.66.194 - -...|
# |NULL|40.77.167.129 - -...|
# |NULL|207.46.13.136 - -...|
# |NULL|40.77.167.129 - -...|
# |NULL|178.253.33.51 - -...|
# |NULL|40.77.167.129 - -...|
# |NULL|91.99.72.15 - - [...|
# |NULL|40.77.167.129 - -...|
# |NULL|207.46.13.136 - -...|
# |NULL|40.77.167.129 - -...|
# |NULL|40.77.167.129 - -...|
# |NULL|66.249.66.194 - -...|
# +----+--------------------+
# only showing top 20 rows
# -------------------------------------------
# Batch: 43
# -------------------------------------------
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|91.99.72.15 - - [...|
# |NULL|130.185.74.243 - ...|
# |NULL|207.46.13.136 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|91.99.72.15 - - [...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|91.99.72.15 - - [...|
# |NULL|130.185.74.243 - ...|
# |NULL|207.46.13.136 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|91.99.72.15 - - [...|
# +----+--------------------+
# -------------------------------------------
# Batch: 44
# -------------------------------------------
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|172.20.2.174 - - ...|
# |NULL|5.217.191.165 - -...|
# |NULL|5.217.191.165 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|172.20.2.174 - - ...|
# |NULL|5.217.191.165 - -...|
# |NULL|5.217.191.165 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
# -------------------------------------------
# Batch: 45
# -------------------------------------------
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|178.131.133.79 - ...|
# |NULL|207.46.13.136 - -...|
# |NULL|31.56.96.51 - - [...|
# |NULL|31.56.96.51 - - [...|
# |NULL|31.56.96.51 - - [...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|178.131.133.79 - ...|
# |NULL|207.46.13.136 - -...|
# |NULL|31.56.96.51 - - [...|
# |NULL|31.56.96.51 - - [...|
# |NULL|31.56.96.51 - - [...|
# +----+--------------------+
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# -------------------------------------------
# Batch: 46
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|31.56.96.51 - - [...|
# |NULL|157.55.39.175 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|66.249.66.194 - -...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|31.56.96.51 - - [...|
# |NULL|157.55.39.175 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|66.249.66.194 - -...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# -------------------------------------------
# Batch: 47
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|5.209.127.187 - -...|
# |NULL|46.224.77.32 - - ...|
# |NULL|46.224.77.32 - - ...|
# |NULL|130.185.74.243 - ...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|5.209.127.187 - -...|
# |NULL|46.224.77.32 - - ...|
# |NULL|46.224.77.32 - - ...|
# |NULL|130.185.74.243 - ...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
# -------------------------------------------
# Batch: 48
# -------------------------------------------
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|54.36.148.135 - -...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|54.36.148.135 - -...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
# -------------------------------------------
# Batch: 49
# -------------------------------------------
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|46.224.77.32 - - ...|
# |NULL|5.209.127.187 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|46.224.77.32 - - ...|
# |NULL|5.209.127.187 - -...|
# +----+--------------------+
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# -------------------------------------------
# Batch: 50
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|66.249.66.91 - - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|207.46.13.136 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|66.249.66.91 - - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|207.46.13.136 - -...|
# +----+--------------------+
#
# -------------------------------------------
# Batch: 51
# -------------------------------------------
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|46.224.77.32 - - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|66.249.66.194 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|46.224.77.32 - - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|66.249.66.194 - -...|
# +----+--------------------+

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /opt/conda/lib/python3.11/site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /opt/conda/lib/python3.11/site-packages (from pyspark) (0.10.9.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
spark.stop()

# %%
query.awaitTermination()
# Out:
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# -------------------------------------------
# Batch: 52
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|157.55.39.175 - -...|
# |NULL|207.46.13.136 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|157.55.39.175 - -...|
# |NULL|207.46.13.136 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
#
# -------------------------------------------
# Batch: 53
# -------------------------------------------
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|204.18.198.248 - ...|
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|204.18.198.248 - ...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|204.18.198.248 - ...|
# |NULL|130.185.74.243 - ...|
# |NULL|157.55.39.175 - -...|
# |NULL|204.18.198.248 - ...|
# |NULL|157.55.39.175 - -...|
# +----+--------------------+
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# -------------------------------------------
# Batch: 54
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|5.209.127.187 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|204.18.198.248 - ...|
# |NULL|17.58.102.43 - - ...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|5.209.127.187 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|204.18.198.248 - ...|
# |NULL|17.58.102.43 - - ...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
#
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# -------------------------------------------
# Batch: 55
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|17.58.102.43 - - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|5.209.127.187 - -...|
# |NULL|5.208.84.157 - - ...|
# |NULL|5.209.127.187 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|17.58.102.43 - - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|5.209.127.187 - -...|
# |NULL|5.208.84.157 - - ...|
# |NULL|5.209.127.187 - -...|
# +----+--------------------+
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# -------------------------------------------
# Batch: 56
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|5.123.209.223 - -...|
# |NULL|5.209.127.187 - -...|
# |NULL|5.209.127.187 - -...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|5.123.209.223 - -...|
# |NULL|5.209.127.187 - -...|
# |NULL|5.209.127.187 - -...|
# |NULL|66.249.66.91 - - ...|
# +----+--------------------+
# -------------------------------------------
# Batch: 57
# -------------------------------------------
# -------------------------------------------
# Batch: 15
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|5.78.180.75 - - [...|
# |NULL|5.209.127.187 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|91.99.72.15 - - [...|
# |NULL|54.36.148.57 - - ...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|5.78.180.75 - - [...|
# |NULL|5.209.127.187 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|91.99.72.15 - - [...|
# |NULL|54.36.148.57 - - ...|
# +----+--------------------+
# -------------------------------------------
# Batch: 58
# -------------------------------------------
# -------------------------------------------
# Batch: 16
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|17.58.102.43 - - ...|
# |NULL|66.249.66.194 - -...|
# |NULL|130.185.74.243 - ...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|5.209.127.187 - -...|
# |NULL|17.58.102.43 - - ...|
# |NULL|66.249.66.194 - -...|
# |NULL|130.185.74.243 - ...|
# +----+--------------------+
# -------------------------------------------
# Batch: 59
# -------------------------------------------
# -------------------------------------------
# Batch: 17
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.194 - -...|
# |NULL|66.249.66.194 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|54.36.148.28 - - ...|
# |NULL|91.99.72.15 - - [...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.194 - -...|
# |NULL|66.249.66.194 - -...|
# |NULL|130.185.74.243 - ...|
# |NULL|54.36.148.28 - - ...|
# |NULL|91.99.72.15 - - [...|
# +----+--------------------+
# -------------------------------------------
# Batch: 60
# -------------------------------------------
# -------------------------------------------
# Batch: 18
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|91.99.72.15 - - [...|
# |NULL|66.249.66.91 - - ...|
# |NULL|31.56.96.51 - - [...|
# |NULL|54.36.148.185 - -...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|66.249.66.91 - - ...|
# |NULL|91.99.72.15 - - [...|
# |NULL|66.249.66.91 - - ...|
# |NULL|31.56.96.51 - - [...|
# |NULL|54.36.148.185 - -...|
# +----+--------------------+
#
# -------------------------------------------
# Batch: 19
# -------------------------------------------
# -------------------------------------------
# Batch: 61
# -------------------------------------------
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|91.99.72.15 - - [...|
# |NULL|130.185.74.243 - ...|
# |NULL|31.56.96.51 - - [...|
# |NULL|31.56.96.51 - - [...|
# +----+--------------------+
#
# +----+--------------------+
# | key|               value|
# +----+--------------------+
# |NULL|130.185.74.243 - ...|
# |NULL|91.99.72.15 - - [...|
# |NULL|130.185.74.243 - ...|
# |NULL|31.56.96.51 - - [...|
# |NULL|31.56.96.51 - - [...|
# +----+--------------------+
